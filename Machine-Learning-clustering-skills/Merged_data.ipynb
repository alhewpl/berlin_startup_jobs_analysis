# %%
import numpy as np
import pandas as pd

# %%
stack_skills = pd.read_csv('DB/stackoverflow_skills.csv')

# %%
bsj_skills = pd.read_csv('DB/bsj_skills.csv')

# %%
frames = [stack_skills, bsj_skills]

# %%
skills = pd.concat(frames)

# %%
skills.head()
# Out:
#    job_id   skill
# 0     553       r
# 1     553  python
# 2     553     sql
# 3     554  python
# 4     554     sql

# %%
bsj_jobs = pd.read_csv('DB/bsj_jobs.csv')
bsj_jobs.head()
# Out:
#    ID company_name                                      jobtitle  \
# 0   1       Fatmap  Mobile Engineer for Outdoor Adventure Sports
# 1   2    AI Engine                              Machine Learning
# 2   3     November         Senior Full Stack PHP Developer (f/m)
# 3   4      Wayfair             Jr. Manager SEO UK (Onpage) (m/f)
# 4   5  CrossEngage                                Data Scientist
#
#                                          description        date  \
# 0  Role & Responsibility: \n\nYou’ll be building ...  2017-10-02
# 1  AI Engine is developing innovative machine lea...  2017-10-02
# 2  Your mission:\n\nDevelopment of a scalable sof...  2017-10-02
# 3  Your tasks:\n\nKeyword research and competitor...  2017-10-02
# 4  About CrossEngage\nCrossEngage is a cloud-base...  2017-10-02
#
#                 source
# 0  Berlin Startup Jobs
# 1  Berlin Startup Jobs
# 2  Berlin Startup Jobs
# 3  Berlin Startup Jobs
# 4  Berlin Startup Jobs

# %%
stack_jobs = pd.read_csv('DB/stackoverflow_jobs.csv')
stack_jobs.head()
# Out:
#      ID                                           jobtitle  \
# 0  1535  Senior PHP Engineer, Marketplace - Turn trips ...
# 1  1536  Senior Frontend Engineer (m/f) at Bonial Inter...
# 2  1537  Senior Frontend Engineer (f/m) at Delivery Her...
# 3  1538  DevOps Engineer (m/f) at CeleraOne GmbH (Berli...
# 4  1539  Java Developer wanted for leading e-hailing ap...
#
#                                          description  \
# 0  Our Marketplace department is looking for a Se...
# 1  What the team lead says about the team:The CDP...
# 2  Delivery Hero is building the next generation ...
# 3  StellenbeschreibungDevelop the future of journ...
# 4  As of now we are looking to recruit a highly m...
#
#                      company_name         source        date
# 0                 GetYourGuide AG  Stackoverflow  2017-11-26
# 1       Bonial International GmbH  Stackoverflow  2017-11-26
# 2                Delivery Hero AG  Stackoverflow  2017-11-26
# ...

# %%
frames2 = [bsj_jobs, stack_jobs]

# %%
jobs = pd.concat(frames2)

# %%
jobs.head(10)
# Out:
#    ID company_name        date  \
# 0   1       Fatmap  2017-10-02
# 1   2    AI Engine  2017-10-02
# 2   3     November  2017-10-02
# 3   4      Wayfair  2017-10-02
# 4   5  CrossEngage  2017-10-02
# 5   6         Ruum  2017-10-02
# 6   7    Auto1.com  2017-10-02
# 7   8      Elinvar  2017-10-02
# 8   9    AI Engine  2017-10-02
# 9  10    PubNative  2017-10-02
#
#                                          description  \
# 0  Role & Responsibility: \n\nYou’ll be building ...
# 1  AI Engine is developing innovative machine lea...
# 2  Your mission:\n\nDevelopment of a scalable sof...
# 3  Your tasks:\n\nKeyword research and competitor...
# 4  About CrossEngage\nCrossEngage is a cloud-base...
# 5  If you’re passionate about learning new techno...
# 6  What you will do:\n\nFull lifecycle engineerin...
# 7  Elinvar offers an integrated solution for asse...
# 8  AI Engine is developing innovative machine lea...
# 9  Your Responsibilities:\n\nUncover new opportun...
#
# ...

# %%
jobs.to_csv('merged_jobs.csv', sep=',')

# %%
skills.to_csv('merged_skills.csv', sep=',')

# %%
merged_skills = pd.read_csv('merged_skills.csv', index_col=0)
merged_skills.head()
# Out:
#    job_id   skill
# 0     553       r
# 1     553  python
# 2     553     sql
# 3     554  python
# 4     554     sql

# %%
merged_skills.keys()
# Out:
# Index(['job_id', 'skill'], dtype='object')

# %%
from sklearn.cluster import KMeans

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.feature_extraction import text

# %%
import nltk.stem
global english_stemmer 
english_stemmer = nltk.stem.SnowballStemmer('english')
class StemmedCountVectorizer(CountVectorizer):
    def build_analyzer(self):
        analyzer = super(CountVectorizer, self).build_analyzer()
        return lambda doc: (english_stemmer.stem(w) for w in analyzer(doc))

# %%
stop_words = ['and','&']
vectorizer = StemmedCountVectorizer(min_df=15, max_df=0.5, stop_words = stop_words)
vectorized = vectorizer.fit_transform(merged_skills['skill'].values.astype('U'))

# %%
num_clusters = 90
km = KMeans(n_clusters = num_clusters, init = 'k-means++', n_init = 1,verbose=1)
clustered = km.fit(vectorized)
predict = km.predict(vectorized)
# Out:
# Initialization complete
# Iteration  0, inertia 49.000
# Iteration  1, inertia 45.353
# Converged at iteration 1: center shift 0.000000e+00 within tolerance 9.122709e-07

# %%
vectorizer.get_feature_names()
# Out:
# ['agil',
#  'android',
#  'angular',
#  'angularj',
#  'ansibl',
#  'apach',
#  'api',
#  'aw',
#  'azur',
#  'cassandra',
#  'chef',
#  'ci',
#  'cloud',
#  'continu',
#  'css',
#  'css3',
#  'django',
#  'docker',
#  'elasticsearch',
#  'es6',
#  'git',
#  'go',
#  'googl',
#  'gulp',
#  'hadoop',
#  'html',
#  'html5',
#  'http',
#  'io',
#  'java',
#  'javascript',
#  'jenkin',
#  'jira',
#  'jqueri',
#  'js',
#  'json',
#  'kafka',
#  'kanban',
#  'kubernet',
#  'laravel',
#  'learn',
#  'less',
#  'linux',
#  'machin',
#  'mongodb',
#  'mysql',
#  'nan',
#  'nativ',
#  'nginx',
#  'node',
#  'nodej',
#  'nosql',
#  'object',
#  'on',
#  'php',
#  'postgresql',
#  'puppet',
#  'python',
#  'rabbitmq',
#  'rail',
#  'react',
#  'reactj',
#  'redi',
#  'redux',
#  'rest',
#  'rubi',
#  'sass',
#  'scala',
#  'scrum',
#  'selenium',
#  'spark',
#  'spring',
#  'sql',
#  'swift',
#  'sysadmin',
#  'tdd',
#  'test',
#  'typescript',
#  'ui',
#  'unix',
#  'vue',
#  'webpack']

# %%
skills
# Out:
#       job_id                   skill
# 0        553                       r
# 1        553                  python
# 2        553                     sql
# 3        554                  python
# 4        554                     sql
# 5        554                       r
# 6        555                  python
# 7        555                  django
# 8        555                     aws
# 9        555                     sql
# 10       555                   scrum
# 11       556                   linux
# 12       556              postgresql
# 13       556                    ceph
# 14       556                  python
# 15       557  continuous-integration
# 16       557                      qa
# 17       557         automated-tests
# 18       557                     sql
# 19       557                  python
# 20       558                  python
# 21       558                     sql
# 22       558           deep-learning
# 23       559                    ruby
# ...

# %%
len(predict)
# Out:
# 4745

# %%
vectorized.shape
# Out:
# (4745, 82)

# %%
len(skills.skill)
# Out:
# 4745

# %%
skills['cluster'] = predict

# %%
skills[skills['cluster'] == 10]
# Out:
#       job_id             skill  cluster
# 115      580               php       10
# 174      592               php       10
# 210      599               php       10
# 287      615               php       10
# 301      617               php       10
# 311      620               php       10
# 341      626               php       10
# 344      627               php       10
# 374      633               php       10
# 391      637               php       10
# 394      638               php       10
# 403      640               php       10
# 457      652               php       10
# 487      658               php       10
# 495      660               php       10
# 508      663               php       10
# 511      663      composer-php       10
# 517      665               php       10
# 538      670               php       10
# 609      686               php       10
# 671      700               php       10
# 710      710               php       10
# ...

# %%
skills.sort_values('cluster').count()
# Out:
# job_id     4745
# skill      4715
# cluster    4745
# dtype: int64

# %%
gg = skills.groupby('cluster')

# %%
import collections, re, operator
from collections import Counter
def BagofWords(textlist):
    bagsofwords = [ collections.Counter(re.findall(r'\w+', txt))
            for txt in textlist]
    words=Counter()
    for bbb in bagsofwords:
        for bb,v in bbb.items():  
            words[bb]+=v
    sorted_words = sorted(words.items(), key=operator.itemgetter(1),reverse=True)
    return sorted_words

# %%
from collections import defaultdict
d=defaultdict()
key=set(predict)
for k in key:
    d[k]=[]
for x,y in gg:
    d[x]+=list(y.skill.values)
    print (y.skill.values)
# Out:
# ['javascript' 'javascript' 'javascript' 'javascript' 'javascript'
#  'javascript' 'javascript' 'javascript' 'javascript' 'javascript'
#  'javascript' 'javascript' 'javascript' 'javascript' 'javascript'
#  'javascript' 'javascript' 'javascript' 'javascript' 'javascript'
#  'javascript' 'javascript' 'javascript' 'javascript' 'javascript'
#  'javascript' 'javascript' 'javascript' 'javascript' 'javascript'
#  'javascript' 'javascript' 'javascript' 'javascript' 'javascript'
#  'javascript' 'javascript' 'javascript' 'javascript' 'javascript'
#  'javascript' 'javascript' 'javascript' 'javascript' 'javascript'
#  'javascript' 'javascript' 'javascript' 'javascript' 'javascript'
#  'javascript' 'javascript' 'javascript' 'javascript' 'javascript'
#  'javascript' 'javascript' 'javascript' 'javascript' 'javascript'
#  'javascript' 'javascript' 'javascript' 'javascript' 'javascript'
#  'javascript' 'javascript' 'javascript' 'javascript' 'javascript'
# ...

# %%
key=6
words = BagofWords(d[key])
print (len(d[key]))
# Out:
# 85

# %%
len(d[7])
# Out:
# 51

# %%
words
# Out:
# [('SQL', 59),
#  ('sql', 25),
#  ('server', 1),
#  ('Transact', 1),
#  ('Server', 1),
#  ('Cloud', 1),
#  ('Sql', 1),
#  ('Injection', 1)]

# %%
skills.sort_values('cluster',ascending=False).to_csv("skills_features_cluster.tsv", encoding='utf8', index=False, sep='\t')

# %%
cluster_type={}

# %%
cluster_type[89] = 'JavaScript frameworks'
cluster_type[88] = 'Sass/LESS' #SASS
cluster_type[87] = 'React.js'
cluster_type[86] = 'scikit-learn / deep learning' 
cluster_type[85] = 'Unix/Linux'
cluster_type[84] = 'Spark' #apache-spark
cluster_type[83] = 'JavaScript frameworks' #vue.js
cluster_type[82] = 'JavaScript frameworks' #javascript es6
cluster_type[81] = 'api' 
cluster_type[80] = 'Unix/Linux' #unix
cluster_type[79] = 'NGINX'
cluster_type[78] = 'Node.js' #node
cluster_type[77] = 'React native'
cluster_type[76] = 'RabbitMQ'
cluster_type[75] = 'Cassandra'
cluster_type[74] = 'JavaScript frameworks' #es6
cluster_type[73] = 'Sass/LESS' #less
cluster_type[72] = 'Gulp'
cluster_type[71] = 'Continuous integration'
cluster_type[70] = 'Node.js' #NodeJS

# %%
cluster_type[69] = 'Django'
cluster_type[68] = 'CI/CD'
cluster_type[67] = 'TDD'
cluster_type[66] = 'Azure'
cluster_type[65] = 'Laravel'
cluster_type[64] = 'HTTP'
cluster_type[63] = 'Cloud'
cluster_type[62] = 'TypeScript'
cluster_type[61] = 'JSON'
cluster_type[60] = 'UI/UX'
cluster_type[59] = 'A/B Testing'
cluster_type[58] = 'Kafka'
cluster_type[57] = 'Redux'
cluster_type[56] = 'Apache Frameworks'
cluster_type[55] = 'Puppet'
cluster_type[54] = 'Chef'
cluster_type[53] = 'sysadmin'
cluster_type[52] = 'Google packages'
cluster_type[51] = 'JQuery'
cluster_type[50] = 'Sass/LESS' #sass

# %%
cluster_type[49] = 'Android'
cluster_type[48] = 'Ansible'
cluster_type[47] = 'Kubernetes'
cluster_type[46] = 'Hadoop'
cluster_type[45] = 'Kanban'
cluster_type[44] = 'iOS'
cluster_type[43] = 'Go'
cluster_type[42] = 'Swift'
cluster_type[41] = 'Agile' 
cluster_type[40] = 'Objective-C'
cluster_type[39] = 'Redis'
cluster_type[38] = 'Angular.js' #angular
cluster_type[37] = 'Selenium'
cluster_type[36] = 'Spring'
cluster_type[35] = ''
cluster_type[34] = 'Webpack'
cluster_type[33] = 'Angular.js' #angularjs
cluster_type[32] = 'Jira'
cluster_type[31] = 'Spark' #spark
cluster_type[30] = 'MongoDB'

# %%
cluster_type[29] = 'React.js' #reactjs
cluster_type[28] = 'RESTful APIs'
cluster_type[27] = 'Machine Learning'
cluster_type[26] = 'Docker'
cluster_type[25] = 'Elasticsearch' 
cluster_type[24] = 'JavaScript frameworks'
cluster_type[23] = 'Scrum' 
cluster_type[22] = 'CSS' #css3
cluster_type[21] = 'Scala'
cluster_type[20] = 'NoSQL'
cluster_type[19] = 'Unix/Linux' #linux
cluster_type[18] = 'React.js' #React
cluster_type[17] = 'Jenkins'
cluster_type[16] = 'MySQL'
cluster_type[15] = 'PostgreSQL'
cluster_type[14] = 'Git'
cluster_type[13] = 'Ruby' #ruby-on-rails #ruby on rails
cluster_type[12] = 'HTML'
cluster_type[11] = 'Java'
cluster_type[10] = 'PHP'

# %%
cluster_type[9] = 'HTML' #html5
cluster_type[8] = 'CSS' #css
cluster_type[7] = 'Node.js' #Node.js
cluster_type[6] = 'SQL'
cluster_type[5] = 'RESTful APIs' #REST
cluster_type[4] = 'Ruby'
cluster_type[3] = 'Python'
cluster_type[2] = 'AWS'
cluster_type[1] = 'mixed'
cluster_type[0] = 'JavaScript'

# %%
CT = pd.DataFrame.from_dict(cluster_type,orient='index')

# %%
CT = CT.reset_index()

# %%
CT.columns = ['cluster','type']

# %%
CT.keys()
# Out:
# Index(['cluster', 'type'], dtype='object')

# %%
skills.head()
# Out:
#    job_id   skill  cluster
# 0     553       r        1
# 1     553  python        3
# 2     553     sql        6
# 3     554  python        3
# 4     554     sql        6

# %%
skills_final = pd.merge(skills, CT, on='cluster')
skills_final = skills_final.drop('cluster', axis=1)
skills_final
# Out:
#       job_id                  skill                   type
# 0        553                      r                  mixed
# 1        554                      r                  mixed
# 2        556                   ceph                  mixed
# 3        557                     qa                  mixed
# 4        563               engineer                  mixed
# 5        563                backend                  mixed
# 6        566                    etl                  mixed
# 7        567                 devops                  mixed
# 8        567                   bash                  mixed
# 9        567             opennebula                  mixed
# 10       568                    etl                  mixed
# 11       568        amazon-redshift                  mixed
# 12       570                    c++                  mixed
# 13       572                 zeromq                  mixed
# 14       573        amazon-redshift                  mixed
# ...
